# %%
import numpy as np
import matplotlib.pyplot as plt

def rk4(t, h, y, n):
    k1 = np.zeros(n)
    k2 = np.zeros(n)
    k3 = np.zeros(n)
    k4 = np.zeros(n)
    k1=h*f(t,y)
    k2=h*f(t+0.5*h,y+0.5*k1)
    k3=h*f(t+0.5*h,y+0.5*k2)
    k4=h*f(t+h,y+k3)
    y=y+(k1+2*k2+2*k3+k4)/6
    return y

def f(t, y):
    f=np.zeros(2)
    f[0]=y[1]
    f[1]=1/(1-t*t)*(2*t*y[1]-n*(n+1)*y[0])
    return f

tend=0.9999
h=.001
yy=1.5
y=[0,yy]
t=0.01
n=5

yp1=[]
while(t<tend):
    if((t+h)>tend):
        h=tend-t
    y = rk4(t,h,y,2)
    yp1=np.append(yp1,y[0])
    t = t+h

tend=0.9999
h=.001
yy=2.5
y=[0,yy]
t=0.01
n=5

yp2=[]
while(t<tend):
    if((t+h)>tend):
        h=tend-t
    y = rk4(t,h,y,2)
    yp2=np.append(yp2,y[0])
    t = t+h
    
tend=0.9999
h=.001
yy=1.875
y=[0,yy]
t=0.01
n=5

yp3=[]
while(t<tend):
    if((t+h)>tend):
        h=tend-t
    y = rk4(t,h,y,2)
    yp3=np.append(yp3,y[0])
    t = t+h
    
plt.title('Legendre Polynomial')
plt.xlabel('X')
plt.ylabel('Y')
plt.plot(x,yp1, label="y'=1.5", linestyle='dashed')
plt.plot(x,yp2, label="y'=2.5", linestyle='dashed')
plt.plot(x,yp3, label="y'=1.875")
plt.legend()
plt.show()
